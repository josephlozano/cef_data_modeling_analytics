# %%
import pandas as pd

# %%
wcc_schools_df = pd.read_csv('cef_provided_files/cef_school_list.csv', encoding='ISO-8859-1',dtype=str)
wcc_schools_df
# Out:
#      #                              School Name Auth (14) Program (16)  \
# 0   18                        Greenwood Academy    WCCUSD    Non-ILCoP
# 1   63  Vista Independent Study/Virtual Academy    WCCUSD    Non-ILCoP
# 2    2       Aspire Richmond Technology Academy    WCCUSD    Non-ILCoP
# 3    3                       Bayview Elementary    WCCUSD        ILCoP
# 4    6               Cesar E. Chavez Elementary    WCCUSD        ILCoP
# ..  ..                                      ...       ...          ...
# 61   1    Aspire Ca College Preparatory Academy    WCCUSD    Non-ILCoP
# 62  25             Invictus Academy of Richmond     CCCOE    Non-ILCoP
# 63  35                     Making Waves Academy     CCCOE    Non-ILCoP
# 64  58                               Summit: K2     CCCOE    Non-ILCoP
# 65  59                        Summit: Tamalpais    WCCUSD    Non-ILCoP
#
#     Charter (14)  Facility (4) School Code  School Type Note
# ...

# %% [markdown]
# # 2023

# %%
expulsion23_df = pd.read_csv('expulsion_data_csv_files/expulsion23.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)

expulsion23_df.columns = [
    'academic_year',
    'aggregate_level',
    'county_code',
    'district_code',
    'school_code',
    'county_name',
    'district_name',
    'school_name',
    'charter_yn',
    'reporting_category',
    'cumulative_enrollment',
    'total_expulsions',
    'expelled_students_total',
    'expelled_students_defiance_only',
    'expulsion_rate_total',
    'expulsion_count_violent_injury',
    'expulsion_count_violent_no_injury',
    'expulsion_count_weapons',
    'expulsion_count_drugs',
    'expulsion_count_defiance',
    'expulsion_count_other'
]
expulsion23_df
# Out:
#        academic_year aggregate_level county_code district_code school_code  \
# 0            2022-23               C          01           NaN         NaN
# 1            2022-23               C          01           NaN         NaN
# 2            2022-23               C          01           NaN         NaN
# 3            2022-23               C          01           NaN         NaN
# 4            2022-23               C          01           NaN         NaN
# ...              ...             ...         ...           ...         ...
# 226174       2022-23               T          00           NaN         NaN
# 226175       2022-23               T          00           NaN         NaN
# 226176       2022-23               T          00           NaN         NaN
# 226177       2022-23               T          00           NaN         NaN
# 226178       2022-23               T          00           NaN         NaN
#
# ...

# %% [markdown]
# # 2022

# %%
expulsion22_df = pd.read_csv('expulsion_data_csv_files/expulsion22-v3.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)

expulsion22_df.columns = [
    'academic_year',
    'aggregate_level',
    'county_code',
    'district_code',
    'school_code',
    'county_name',
    'district_name',
    'school_name',
    'charter_yn',
    'reporting_category',
    'cumulative_enrollment',
    'total_expulsions',
    'expelled_students_total',
    'expelled_students_defiance_only',
    'expulsion_rate_total',
    'expulsion_count_violent_injury',
    'expulsion_count_violent_no_injury',
    'expulsion_count_weapons',
    'expulsion_count_drugs',
    'expulsion_count_defiance',
    'expulsion_count_other'
]

expulsion22_df
# Out:
#        academic_year aggregate_level county_code district_code school_code  \
# 0            2021-22               C          01           NaN         NaN
# 1            2021-22               C          01           NaN         NaN
# 2            2021-22               C          01           NaN         NaN
# 3            2021-22               C          01           NaN         NaN
# 4            2021-22               C          01           NaN         NaN
# ...              ...             ...         ...           ...         ...
# 225348       2021-22               T          00           NaN         NaN
# 225349       2021-22               T          00           NaN         NaN
# 225350       2021-22               T          00           NaN         NaN
# 225351       2021-22               T          00           NaN         NaN
# 225352       2021-22               T          00           NaN         NaN
#
# ...

# %% [markdown]
# # 2021

# %%
expulsion21_df = pd.read_csv('expulsion_data_csv_files/expulsion21.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)

expulsion21_df.columns = [
    'academic_year',
    'aggregate_level',
    'county_code',
    'district_code',
    'school_code',
    'county_name',
    'district_name',
    'school_name',
    'charter_yn',
    'reporting_category',
    'cumulative_enrollment',
    'total_expulsions',
    'expelled_students_total',
    'expelled_students_defiance_only',
    'expulsion_rate_total',
    'expulsion_count_violent_injury',
    'expulsion_count_violent_no_injury',
    'expulsion_count_weapons',
    'expulsion_count_drugs',
    'expulsion_count_defiance',
    'expulsion_count_other'
]

expulsion21_df
# Out:
#        academic_year aggregate_level county_code district_code school_code  \
# 0            2020-21               C          01           NaN         NaN
# 1            2020-21               C          01           NaN         NaN
# 2            2020-21               C          01           NaN         NaN
# 3            2020-21               C          01           NaN         NaN
# 4            2020-21               C          01           NaN         NaN
# ...              ...             ...         ...           ...         ...
# 222802       2020-21               T          00           NaN         NaN
# 222803       2020-21               T          00           NaN         NaN
# 222804       2020-21               T          00           NaN         NaN
# 222805       2020-21               T          00           NaN         NaN
# 222806       2020-21               T          00           NaN         NaN
#
# ...

# %% [markdown]
# # 2020

# %%
expulsion20_df = pd.read_csv('expulsion_data_csv_files/expulsion20.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)

expulsion20_df.columns = [
    'academic_year',
    'aggregate_level',
    'county_code',
    'district_code',
    'school_code',
    'county_name',
    'district_name',
    'school_name',
    'charter_yn',
    'reporting_category',
    'cumulative_enrollment',
    'total_expulsions',
    'expelled_students_total',
    'expelled_students_defiance_only',
    'expulsion_rate_total',
    'expulsion_count_violent_injury',
    'expulsion_count_violent_no_injury',
    'expulsion_count_weapons',
    'expulsion_count_drugs',
    'expulsion_count_defiance',
    'expulsion_count_other'
]

expulsion20_df
# Out:
#        academic_year aggregate_level county_code district_code school_code  \
# 0            2019-20               C          01           NaN         NaN
# 1            2019-20               C          01           NaN         NaN
# 2            2019-20               C          01           NaN         NaN
# 3            2019-20               C          01           NaN         NaN
# 4            2019-20               C          01           NaN         NaN
# ...              ...             ...         ...           ...         ...
# 223628       2019-20               T          00           NaN         NaN
# 223629       2019-20               T          00           NaN         NaN
# 223630       2019-20               T          00           NaN         NaN
# 223631       2019-20               T          00           NaN         NaN
# 223632       2019-20               T          00           NaN         NaN
#
# ...

# %% [markdown]
# # 2019

# %%
expulsion19_df = pd.read_csv('expulsion_data_csv_files/expulsion19.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)

expulsion19_df.columns = [
    'academic_year',
    'aggregate_level',
    'county_code',
    'district_code',
    'school_code',
    'county_name',
    'district_name',
    'school_name',
    'charter_yn',
    'reporting_category',
    'cumulative_enrollment',
    'total_expulsions',
    'expelled_students_total',
    'expelled_students_defiance_only',
    'expulsion_rate_total',
    'expulsion_count_violent_injury',
    'expulsion_count_violent_no_injury',
    'expulsion_count_weapons',
    'expulsion_count_drugs',
    'expulsion_count_defiance',
    'expulsion_count_other'
]

expulsion19_df
# Out:
#        academic_year aggregate_level county_code district_code school_code  \
# 0            2018-19               C          01           NaN         NaN
# 1            2018-19               C          01           NaN         NaN
# 2            2018-19               C          01           NaN         NaN
# 3            2018-19               C          01           NaN         NaN
# 4            2018-19               C          01           NaN         NaN
# ...              ...             ...         ...           ...         ...
# 355142       2018-19               T          00           NaN         NaN
# 355143       2018-19               T          00           NaN         NaN
# 355144       2018-19               T          00           NaN         NaN
# 355145       2018-19               T          00           NaN         NaN
# 355146       2018-19               T          00           NaN         NaN
#
# ...

# %% [markdown]
# # 2018

# %%
expulsion18_df = pd.read_csv('expulsion_data_csv_files/expulsion18.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)

expulsion18_df.columns = [
    'academic_year',
    'aggregate_level',
    'county_code',
    'district_code',
    'school_code',
    'county_name',
    'district_name',
    'school_name',
    'charter_yn',
    'reporting_category',
    'cumulative_enrollment',
    'total_expulsions',
    'expelled_students_total',
    'expelled_students_defiance_only',
    'expulsion_rate_total',
    'expulsion_count_violent_injury',
    'expulsion_count_violent_no_injury',
    'expulsion_count_weapons',
    'expulsion_count_drugs',
    'expulsion_count_defiance',
    'expulsion_count_other'
]

expulsion18_df
# Out:
#        academic_year aggregate_level county_code district_code school_code  \
# 0            2017-18               C          01           NaN         NaN
# 1            2017-18               C          01           NaN         NaN
# 2            2017-18               C          01           NaN         NaN
# 3            2017-18               C          01           NaN         NaN
# 4            2017-18               C          01           NaN         NaN
# ...              ...             ...         ...           ...         ...
# 355499       2017-18               T          00           NaN         NaN
# 355500       2017-18               T          00           NaN         NaN
# 355501       2017-18               T          00           NaN         NaN
# 355502       2017-18               T          00           NaN         NaN
# 355503       2017-18               T          00           NaN         NaN
#
# ...

# %%
final_expulsion_df = pd.concat([expulsion23_df, expulsion22_df, expulsion21_df, expulsion20_df, expulsion19_df, expulsion18_df])
final_expulsion_df
# Out:
#        academic_year aggregate_level county_code district_code school_code  \
# 0            2022-23               C          01           NaN         NaN
# 1            2022-23               C          01           NaN         NaN
# 2            2022-23               C          01           NaN         NaN
# 3            2022-23               C          01           NaN         NaN
# 4            2022-23               C          01           NaN         NaN
# ...              ...             ...         ...           ...         ...
# 355499       2017-18               T          00           NaN         NaN
# 355500       2017-18               T          00           NaN         NaN
# 355501       2017-18               T          00           NaN         NaN
# 355502       2017-18               T          00           NaN         NaN
# 355503       2017-18               T          00           NaN         NaN
#
# ...

# %%
# Step 1: Create a set of unique school codes from the wcc school list for efficient lookup
wcc_schools_list = set(wcc_schools_df['School Code'])

# Step 2: Use the .isin() method to check if each school code in dataframe1 is in the set of schools from dataframe2
final_expulsion_df['is_wcc_entity'] = final_expulsion_df['school_code'].isin(wcc_schools_list)

final_expulsion_df
# Out:
#        academic_year aggregate_level county_code district_code school_code  \
# 0            2022-23               C          01           NaN         NaN
# 1            2022-23               C          01           NaN         NaN
# 2            2022-23               C          01           NaN         NaN
# 3            2022-23               C          01           NaN         NaN
# 4            2022-23               C          01           NaN         NaN
# ...              ...             ...         ...           ...         ...
# 355499       2017-18               T          00           NaN         NaN
# 355500       2017-18               T          00           NaN         NaN
# 355501       2017-18               T          00           NaN         NaN
# 355502       2017-18               T          00           NaN         NaN
# 355503       2017-18               T          00           NaN         NaN
#
# ...

# %%
# Existing conditions for "Aggregate Level" and "is_wcc_entity"
condition1 = final_expulsion_df['aggregate_level'].isin(['T', 'D'])
condition2 = final_expulsion_df['is_wcc_entity']

# New conditions to exclude rows with "*" in the chronic absenteeism columns
condition3 = ~final_expulsion_df['cumulative_enrollment'].str.contains('*', regex=False)

# Combine all conditions using "AND" (&) for the chronic absenteeism conditions and "OR" (|) for the initial conditions
combined_condition = (condition1 | condition2) & (condition3)

# Filter dataframe1 using the combined condition
final_filtered_expulsion_df = final_expulsion_df[combined_condition]

final_filtered_expulsion_df
# Out:
#        academic_year aggregate_level county_code district_code school_code  \
# 3152         2022-23               D          01         10017     0000000
# 3153         2022-23               D          01         10017     0000000
# 3155         2022-23               D          01         10017     0000000
# 3156         2022-23               D          01         10017     0000000
# 3157         2022-23               D          01         10017     0000000
# ...              ...             ...         ...           ...         ...
# 355499       2017-18               T          00           NaN         NaN
# 355500       2017-18               T          00           NaN         NaN
# 355501       2017-18               T          00           NaN         NaN
# 355502       2017-18               T          00           NaN         NaN
# 355503       2017-18               T          00           NaN         NaN
#
# ...

# %%
final_filtered_expulsion_df.to_csv('final_long_datasets_domain/final_expulsion_df.csv', index=False)
