# %%
import pandas as pd

# %%
wcc_schools_df = pd.read_csv('cef_provided_files/cef_school_list.csv', encoding='ISO-8859-1',dtype=str)
wcc_schools_df
# Out:
#      #                              School Name Auth (14) Program (16)  \
# 0   18                        Greenwood Academy    WCCUSD    Non-ILCoP
# 1   63  Vista Independent Study/Virtual Academy    WCCUSD    Non-ILCoP
# 2    2       Aspire Richmond Technology Academy    WCCUSD    Non-ILCoP
# 3    3                       Bayview Elementary    WCCUSD        ILCoP
# 4    6               Cesar E. Chavez Elementary    WCCUSD        ILCoP
# ..  ..                                      ...       ...          ...
# 61   1    Aspire Ca College Preparatory Academy    WCCUSD    Non-ILCoP
# 62  25             Invictus Academy of Richmond     CCCOE    Non-ILCoP
# 63  35                     Making Waves Academy     CCCOE    Non-ILCoP
# 64  58                               Summit: K2     CCCOE    Non-ILCoP
# 65  59                        Summit: Tamalpais    WCCUSD    Non-ILCoP
#
#     Charter (14)  Facility (4) School Code  School Type Note
# ...

# %% [markdown]
# # 2023

# %%
enrollment_el_2023_df = pd.read_csv('enrollment_el_csv_files_exported/LtelDownload2223.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)
enrollment_el_2023_df
# Out:
#        AcademicYear CountyCode DistrictCode SchoolCode CountyName  \
# 0           2022-23        NaN          NaN        NaN        NaN
# 1           2022-23        NaN          NaN        NaN        NaN
# 2           2022-23        NaN          NaN        NaN        NaN
# 3           2022-23        NaN          NaN        NaN        NaN
# 4           2022-23        NaN          NaN        NaN        NaN
# ...             ...        ...          ...        ...        ...
# 218995      2022-23         58        72736    6056782       Yuba
# 218996      2022-23         58        72751    6056816       Yuba
# 218997      2022-23         58        72751    6118806       Yuba
# 218998      2022-23         58        72769    0123570       Yuba
# 218999      2022-23         58        72769    5838305       Yuba
#
#                     DistrictName                    SchoolName Charter  \
# 0                            NaN                           NaN     NaN
# ...

# %% [markdown]
# # 2022

# %%
enrollment_el_2022_df = pd.read_csv('enrollment_el_csv_files_exported/LtelDownload2122.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)
enrollment_el_2022_df
# Out:
#        AcademicYear CountyCode DistrictCode SchoolCode CountyName  \
# 0           2021-22        NaN          NaN        NaN        NaN
# 1           2021-22        NaN          NaN        NaN        NaN
# 2           2021-22        NaN          NaN        NaN        NaN
# 3           2021-22        NaN          NaN        NaN        NaN
# 4           2021-22        NaN          NaN        NaN        NaN
# ...             ...        ...          ...        ...        ...
# 216996      2021-22         58        72751    6056816       Yuba
# 216997      2021-22         58        72751    6118806       Yuba
# 216998      2021-22         58        72769    0000001       Yuba
# 216999      2021-22         58        72769    0123570       Yuba
# 217000      2021-22         58        72769    5838305       Yuba
#
#                 DistrictName                       SchoolName Charter  \
# 0                        NaN                              NaN     NaN
# ...

# %% [markdown]
# # 2021

# %%
enrollment_el_2021_df = pd.read_csv('enrollment_el_csv_files_exported/LtelDownload2021.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)
enrollment_el_2021_df
# Out:
#        AcademicYear CountyCode DistrictCode SchoolCode CountyName  \
# 0           2020-21        NaN          NaN        NaN        NaN
# 1           2020-21        NaN          NaN        NaN        NaN
# 2           2020-21        NaN          NaN        NaN        NaN
# 3           2020-21        NaN          NaN        NaN        NaN
# 4           2020-21        NaN          NaN        NaN        NaN
# ...             ...        ...          ...        ...        ...
# 213413      2020-21         58        72744    0107375       Yuba
# 213414      2020-21         58        72751    6056832       Yuba
# 213415      2020-21         58        72751    6056832       Yuba
# 213416      2020-21         58        72751    6056840       Yuba
# 213417      2020-21         58        72751    6056840       Yuba
#
#                   DistrictName              SchoolName Charter AggLevel Grade  \
# 0                          NaN                     NaN     NaN        T    01
# ...

# %% [markdown]
# # 2020

# %%
enrollment_el_2020_df = pd.read_csv('enrollment_el_csv_files_exported/LtelDownload1920.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)
enrollment_el_2020_df
# Out:
#        AcademicYear CountyCode DistrictCode SchoolCode CountyName  \
# 0           2019-20        NaN          NaN        NaN        NaN
# 1           2019-20        NaN          NaN        NaN        NaN
# 2           2019-20        NaN          NaN        NaN        NaN
# 3           2019-20        NaN          NaN        NaN        NaN
# 4           2019-20        NaN          NaN        NaN        NaN
# ...             ...        ...          ...        ...        ...
# 212091      2019-20         58        72744    0107375       Yuba
# 212092      2019-20         58        72751    6056832       Yuba
# 212093      2019-20         58        72751    6056832       Yuba
# 212094      2019-20         58        72751    6056840       Yuba
# 212095      2019-20         58        72751    6056840       Yuba
#
#                   DistrictName              SchoolName Charter AggLevel Grade  \
# 0                          NaN                     NaN     NaN        T    01
# ...

# %% [markdown]
# # 2019

# %%
enrollment_el_2019_df = pd.read_csv('enrollment_el_csv_files_exported/LtelDownload1819.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)
enrollment_el_2019_df
# Out:
#        AcademicYear CountyCode DistrictCode SchoolCode CountyName  \
# 0           2018-19        NaN          NaN        NaN        NaN
# 1           2018-19        NaN          NaN        NaN        NaN
# 2           2018-19        NaN          NaN        NaN        NaN
# 3           2018-19        NaN          NaN        NaN        NaN
# 4           2018-19        NaN          NaN        NaN        NaN
# ...             ...        ...          ...        ...        ...
# 210811      2018-19         58        72736    6099014       Yuba
# 210812      2018-19         58        72736    6099014       Yuba
# 210813      2018-19         58        72744    0107375       Yuba
# 210814      2018-19         58        72744    0114652       Yuba
# 210815      2018-19         58        72769    0000001       Yuba
#
#                     DistrictName                       SchoolName Charter  \
# 0                            NaN                              NaN     NaN
# ...

# %% [markdown]
# # 2018

# %%
enrollment_el_2018_df = pd.read_csv('enrollment_el_csv_files_exported/LtelDownload1718.csv', encoding='ISO-8859-1',dtype=str)
pd.set_option('display.max_columns', None)
enrollment_el_2018_df
# Out:
#        AcademicYear CountyCode DistrictCode SchoolCode CountyName  \
# 0           2017-18        NaN          NaN        NaN        NaN
# 1           2017-18        NaN          NaN        NaN        NaN
# 2           2017-18        NaN          NaN        NaN        NaN
# 3           2017-18        NaN          NaN        NaN        NaN
# 4           2017-18        NaN          NaN        NaN        NaN
# ...             ...        ...          ...        ...        ...
# 210716      2017-18         58        72736    6056725       Yuba
# 210717      2017-18         58        72736    6056741       Yuba
# 210718      2017-18         58        72736    6056782       Yuba
# 210719      2017-18         58        72751    6118806       Yuba
# 210720      2017-18         58        72751    6118806       Yuba
#
#                     DistrictName                 SchoolName Charter AggLevel  \
# 0                            NaN                        NaN     NaN        T
# ...

# %%
final_enrollment_el_df = pd.concat([enrollment_el_2023_df, enrollment_el_2022_df, enrollment_el_2021_df, enrollment_el_2020_df, enrollment_el_2019_df, enrollment_el_2018_df])
final_enrollment_el_df
# Out:
#        AcademicYear CountyCode DistrictCode SchoolCode CountyName  \
# 0           2022-23        NaN          NaN        NaN        NaN
# 1           2022-23        NaN          NaN        NaN        NaN
# 2           2022-23        NaN          NaN        NaN        NaN
# 3           2022-23        NaN          NaN        NaN        NaN
# 4           2022-23        NaN          NaN        NaN        NaN
# ...             ...        ...          ...        ...        ...
# 210716      2017-18         58        72736    6056725       Yuba
# 210717      2017-18         58        72736    6056741       Yuba
# 210718      2017-18         58        72736    6056782       Yuba
# 210719      2017-18         58        72751    6118806       Yuba
# 210720      2017-18         58        72751    6118806       Yuba
#
#                     DistrictName                 SchoolName Charter AggLevel  \
# 0                            NaN                        NaN     NaN        T
# ...

# %%
final_enrollment_el_df.loc[final_enrollment_el_df['AggLevel'] == 'T', 'CountyCode'] = '00'
final_enrollment_el_df.loc[final_enrollment_el_df['AggLevel'] == 'T', 'DistrictCode'] = '00000'
final_enrollment_el_df.loc[final_enrollment_el_df['AggLevel'] == 'T', 'SchoolCode'] = '0000000'

final_enrollment_el_df['Charter'] = final_enrollment_el_df['Charter'].fillna('NV').replace('', 'NV')

# %%
final_enrollment_el_df.loc[final_enrollment_el_df['AggLevel'] == 'D', 'SchoolCode'] = '0000000'

# %%
final_enrollment_el_df[final_enrollment_el_df['AggLevel'] == 'D']

# D = Local educational agency totals (includes districts and direct funded charter schools)
# O = County totals
# S = School totals
# T = State totals
# Out:
#       AcademicYear CountyCode DistrictCode SchoolCode CountyName  \
# 2786       2022-23         01        10017    0000000    Alameda
# 2787       2022-23         01        10017    0000000    Alameda
# 2788       2022-23         01        10017    0000000    Alameda
# 2789       2022-23         01        10017    0000000    Alameda
# 2790       2022-23         01        31609    0000000    Alameda
# ...            ...        ...          ...        ...        ...
# 34407      2017-18         58        10587    0000000       Yuba
# 34408      2017-18         58        72728    0000000       Yuba
# 34409      2017-18         58        72736    0000000       Yuba
# 34410      2017-18         58        72744    0000000       Yuba
# 34411      2017-18         58        72751    0000000       Yuba
#
#                                             DistrictName SchoolName Charter  \
# 2786                  Alameda County Office of Education        NaN      NV
# ...

# %%
final_enrollment_el_df.Charter.unique()
# Out:
# array(['NV', 'Y', 'N'], dtype=object)

# %%
# Columns to convert to integer
convert_columns = [
    'EO', 'IFEP', 'EL', 'RFEP', 'TBD', 'TotalEnrollment', 'AR', 'LTEL',
    'EL4+', 'EL03Y', 'EL45Y', 'EL6+Y', 'Total-EE'
]

# Convert specified columns from strings to integers (handling missing or malformed data)
for column in convert_columns:
    final_enrollment_el_df[column] = pd.to_numeric(final_enrollment_el_df[column], errors='coerce').fillna(0).astype(int)

# Group by columns
group_columns = [
    'AcademicYear', 'CountyCode', 'DistrictCode', 'SchoolCode',  'AggLevel', 'Gender'
]

# Group the data and sum the specified columns
final_enrollment_el_df = final_enrollment_el_df.groupby(group_columns)[convert_columns].sum().reset_index()
final_enrollment_el_df
# Out:
#        AcademicYear CountyCode DistrictCode SchoolCode AggLevel Gender  \
# 0           2017-18         00        00000    0000000        T    ALL
# 1           2017-18         00        00000    0000000        T      F
# 2           2017-18         00        00000    0000000        T      M
# 3           2017-18         01        10017    0000000        D    ALL
# 4           2017-18         01        10017    0000000        D      F
# ...             ...        ...          ...        ...      ...    ...
# 212565      2022-23         58        72769    0133751        S      M
# 212566      2022-23         58        72769    5838305        S    ALL
# 212567      2022-23         58        72769    5838305        S      F
# 212568      2022-23         58        72769    5838305        S      M
# 212569      2022-23         58        72769    5838305        S      X
#
#              EO    IFEP       EL     RFEP    TBD  TotalEnrollment      AR  \
# ...

# %%
# Step 1: Create a set of unique school codes from dataframe2 for efficient lookup
wcc_schools_list = set(wcc_schools_df['School Code'])

# Step 2: Use the .isin() method to check if each school code in dataframe1 is in the set of schools from dataframe2
final_enrollment_el_df['is_wcc_entity'] = final_enrollment_el_df['SchoolCode'].isin(wcc_schools_list)

# %%
# Existing conditions for "Aggregate Level" and "is_wcc_entity"
condition1 = final_enrollment_el_df['AggLevel'].isin(['T', 'D'])
condition2 = final_enrollment_el_df['is_wcc_entity']

# Combine all conditions using "OR" (|) for the initial conditions
combined_condition = (condition1 | condition2) 

# Filter dataframe1 using the combined condition
final_filtered_enrollment_el_df = final_enrollment_el_df[combined_condition]

# %%
final_filtered_enrollment_el_df
# Out:
#        AcademicYear CountyCode DistrictCode SchoolCode AggLevel Gender  \
# 0           2017-18         00        00000    0000000        T    ALL
# 1           2017-18         00        00000    0000000        T      F
# 2           2017-18         00        00000    0000000        T      M
# 3           2017-18         01        10017    0000000        D    ALL
# 4           2017-18         01        10017    0000000        D      F
# ...             ...        ...          ...        ...      ...    ...
# 212543      2022-23         58        72751    0000000        D      M
# 212556      2022-23         58        72769    0000000        D    ALL
# 212557      2022-23         58        72769    0000000        D      F
# 212558      2022-23         58        72769    0000000        D      M
# 212559      2022-23         58        72769    0000000        D      X
#
#              EO    IFEP       EL     RFEP    TBD  TotalEnrollment      AR  \
# ...

# %%
# Define a dictionary with the mappings from old values to new values
replacement_dict = {
    'ALL': 'TA',
    'F': 'GF',
    'M': 'GM',
    'X': 'GX'
}

# Replace the values in the 'Gender' column
final_filtered_enrollment_el_df['Gender'] = final_filtered_enrollment_el_df['Gender'].replace(replacement_dict)
final_filtered_enrollment_el_df
# Out:
# /var/folders/6t/n3rqwc2x06ngf2r8521g1nmc0000gn/T/ipykernel_20635/1372549556.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_filtered_enrollment_el_df['Gender'] = final_filtered_enrollment_el_df['Gender'].replace(replacement_dict)
#        AcademicYear CountyCode DistrictCode SchoolCode AggLevel Gender  \
# 0           2017-18         00        00000    0000000        T     TA
# 1           2017-18         00        00000    0000000        T     GF
# 2           2017-18         00        00000    0000000        T     GM
# 3           2017-18         01        10017    0000000        D     TA
# 4           2017-18         01        10017    0000000        D     GF
# ...

# %%
# Dictionary mapping old column names to new ones
rename_dict = {
    'AcademicYear': 'academic_year',
    'CountyCode': 'county_code',
    'DistrictCode': 'district_code',
    'SchoolCode': 'school_code',
    'AggLevel': 'aggregate_level',
    'Gender': 'reporting_category' 
}

# Rename the columns using the dictionary
final_filtered_enrollment_el_df = final_filtered_enrollment_el_df.rename(columns=rename_dict)
final_filtered_enrollment_el_df
# Out:
#        academic_year county_code district_code school_code aggregate_level  \
# 0            2017-18          00         00000     0000000               T
# 1            2017-18          00         00000     0000000               T
# 2            2017-18          00         00000     0000000               T
# 3            2017-18          01         10017     0000000               D
# 4            2017-18          01         10017     0000000               D
# ...              ...         ...           ...         ...             ...
# 212543       2022-23          58         72751     0000000               D
# 212556       2022-23          58         72769     0000000               D
# 212557       2022-23          58         72769     0000000               D
# 212558       2022-23          58         72769     0000000               D
# 212559       2022-23          58         72769     0000000               D
#
# ...

# %%
# Columns you want to remove
columns_to_drop = ['is_wcc_entity' ]

# Drop the specified columns
final_filtered_enrollment_el_df = final_filtered_enrollment_el_df.drop(columns=columns_to_drop)
final_filtered_enrollment_el_df
# Out:
#        academic_year county_code district_code school_code aggregate_level  \
# 0            2017-18          00         00000     0000000               T
# 1            2017-18          00         00000     0000000               T
# 2            2017-18          00         00000     0000000               T
# 3            2017-18          01         10017     0000000               D
# 4            2017-18          01         10017     0000000               D
# ...              ...         ...           ...         ...             ...
# 212543       2022-23          58         72751     0000000               D
# 212556       2022-23          58         72769     0000000               D
# 212557       2022-23          58         72769     0000000               D
# 212558       2022-23          58         72769     0000000               D
# 212559       2022-23          58         72769     0000000               D
#
# ...

# %%
final_filtered_enrollment_el_df.to_csv('final_long_datasets_domain/final_enrollment_el_df.csv', index=False)
